# %% [markdown]
# <a href="https://colab.research.google.com/github/shigophilo/ai/blob/main/demo/vibevoice_realtime_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # VibeVoice-Realtime Colab — T4 Quickstart

# %% [markdown]
# ## Step 1: Setup Environment

# %%
# !git clone https://github.com/vibevoice-community/VibeVoice.git

# Download model
from huggingface_hub import snapshot_download
snapshot_download("microsoft/VibeVoice-Realtime-0.5B", local_dir="/content/models/VibeVoice-Realtime-0.5B")
print("✅ Downloaded model: microsoft/VibeVoice-Realtime-0.5B")
# Out:
# Cloning into 'VibeVoice'...
# remote: Enumerating objects: 684, done.
# remote: Counting objects: 100% (253/253), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 684 (delta 217), reused 180 (delta 177), pack-reused 431 (from 2)
# Receiving objects: 100% (684/684), 55.77 MiB | 23.74 MiB/s, done.
# Resolving deltas: 100% (397/397), done.
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# ✅ Downloaded model: microsoft/VibeVoice-Realtime-0.5B

# %% [markdown]
# [Optional] If the download exceeds 1 minute, it is probably stuck. You can: (1) interrupt the execution, (2) log in to Hugging Face, and (3) try download again.

# %%
# !bash python /content/VibeVoice/demo/gradio_demo.py --model_path /content/VibeVoice/models/VibeVoice-Realtime-0.5B --share
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# 2025-12-26 08:25:31.078795: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-26 08:25:31.111429: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-26 08:25:31.183137: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766737531.246546   22343 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766737531.260456   22343 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766737531.314673   22343 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766737531.314752   22343 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766737531.314758   22343 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766737531.314763   22343 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-26 08:25:31.330772: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-26 08:25:31.078795: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-26 08:25:31.111429: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-12-26 08:25:31.183137: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766737531.246546   22343 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766737531.260456   22343 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766737531.314673   22343 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766737531.314752   22343 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766737531.314758   22343 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766737531.314763   22343 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-26 08:25:31.330772: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Traceback (most recent call last):
#   File "/content/VibeVoice/demo/gradio_demo.py", line 24, in <module>
#     from vibevoice.modular.configuration_vibevoice import VibeVoiceConfig
#   File "/content/VibeVoice/vibevoice/modular/__init__.py", line 16, in <module>
#     from .modeling_vibevoice import (
#   File "/content/VibeVoice/vibevoice/modular/modeling_vibevoice.py", line 13, in <module>
#     from transformers.models.llama.modeling_llama import LlamaRMSNorm
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/llama/modeling_llama.py", line 40, in <module>
#     from ...modeling_utils import ALL_ATTENTION_FUNCTIONS, PreTrainedModel
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py", line 69, in <module>
#     from .loss.loss_utils import LOSS_MAPPING
#   File "/usr/local/lib/python3.12/dist-packages/transformers/loss/loss_utils.py", line 21, in <module>
#     from .loss_deformable_detr import DeformableDetrForObjectDetectionLoss, DeformableDetrForSegmentationLoss
#   File "/usr/local/lib/python3.12/dist-packages/transformers/loss/loss_deformable_detr.py", line 4, in <module>
#     from ..image_transforms import center_to_corners_format
#   File "/usr/local/lib/python3.12/dist-packages/transformers/image_transforms.py", line 47, in <module>
#     import tensorflow as tf
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/__init__.py", line 49, in <module>
#     from tensorflow._api.v2 import __internal__
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/_api/v2/__internal__/__init__.py", line 11, in <module>
#     from tensorflow._api.v2.__internal__ import distribute
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/_api/v2/__internal__/distribute/__init__.py", line 8, in <module>
#     from tensorflow._api.v2.__internal__.distribute import combinations
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/_api/v2/__internal__/distribute/combinations/__init__.py", line 8, in <module>
#     from tensorflow.python.distribute.combinations import env # line: 456
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/distribute/combinations.py", line 33, in <module>
#     from tensorflow.python.distribute import collective_all_reduce_strategy
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/distribute/collective_all_reduce_strategy.py", line 26, in <module>
#     from tensorflow.python.distribute import cross_device_ops as cross_device_ops_lib
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/distribute/cross_device_ops.py", line 28, in <module>
#     from tensorflow.python.distribute import cross_device_utils
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/distribute/cross_device_utils.py", line 22, in <module>
#     from tensorflow.python.distribute import values as value_lib
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/distribute/values.py", line 23, in <module>
#     from tensorflow.python.distribute import distribute_lib
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/distribute/distribute_lib.py", line 205, in <module>
#     from tensorflow.python.data.ops import dataset_ops
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/data/__init__.py", line 21, in <module>
#     from tensorflow.python.data import experimental
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/data/experimental/__init__.py", line 99, in <module>
#     from tensorflow.python.data.experimental import service
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/data/experimental/service/__init__.py", line 419, in <module>
#     from tensorflow.python.data.experimental.ops.data_service_ops import distribute
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/data/experimental/ops/data_service_ops.py", line 23, in <module>
#     from tensorflow.python.data.experimental.ops import compression_ops
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/data/experimental/ops/compression_ops.py", line 16, in <module>
#     from tensorflow.python.data.util import structure
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/data/util/structure.py", line 32, in <module>
#     from tensorflow.python.ops.ragged import ragged_tensor
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/ragged/__init__.py", line 28, in <module>
#     from tensorflow.python.ops.ragged import ragged_tensor
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/ragged/ragged_tensor.py", line 3149, in <module>
#     from tensorflow.python.ops.ragged import ragged_ops  # pylint: disable=unused-import, g-bad-import-order, g-import-not-at-top
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/ragged/ragged_ops.py", line 41, in <module>
#     from tensorflow.python.ops.ragged import ragged_image_ops
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/ragged/ragged_image_ops.py", line 24, in <module>
#     from tensorflow.python.ops import image_ops
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/image_ops.py", line 159, in <module>
#     from tensorflow.python.ops.image_ops_impl import *
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/image_ops_impl.py", line 40, in <module>
#     from tensorflow.python.ops import nn_impl
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/nn_impl.py", line 26, in <module>
#     from tensorflow.python.ops import ctc_ops  # pylint: disable=unused-import
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/ctc_ops.py", line 32, in <module>
#     from tensorflow.python.ops import custom_gradient
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/custom_gradient.py", line 17, in <module>
#     from tensorflow.python.eager import backprop
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/backprop.py", line 45, in <module>
#     from tensorflow.python.ops import gradients_impl  # pylint: disable=unused-import
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/gradients_impl.py", line 33, in <module>
#     from tensorflow.python.ops import math_grad  # pylint: disable=unused-import
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/math_grad.py", line 1215, in <module>
#     @ops.RegisterGradient("Polygamma")
#      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py", line 1722, in __call__
#     gradient_registry.register(f, self._op_type)
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/registry.py", line 65, in register
#     stack = traceback.extract_stack(limit=3)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/traceback.py", line 232, in extract_stack
#     stack = StackSummary.extract(walk_stack(f), limit=limit)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/traceback.py", line 395, in extract
#     return klass._extract_from_extended_frame_gen(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/traceback.py", line 434, in _extract_from_extended_frame_gen
#     linecache.checkcache(filename)
#   File "/usr/lib/python3.12/linecache.py", line 75, in checkcache
#     stat = os.stat(fullname)
#            ^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/content/VibeVoice/demo/gradio_demo.py", line 24, in <module>
#     from vibevoice.modular.configuration_vibevoice import VibeVoiceConfig
#   File "/content/VibeVoice/vibevoice/modular/__init__.py", line 16, in <module>
#     from .modeling_vibevoice import (
#   File "/content/VibeVoice/vibevoice/modular/modeling_vibevoice.py", line 13, in <module>
#     from transformers.models.llama.modeling_llama import LlamaRMSNorm
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/llama/modeling_llama.py", line 40, in <module>
#     from ...modeling_utils import ALL_ATTENTION_FUNCTIONS, PreTrainedModel
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_utils.py", line 69, in <module>
#     from .loss.loss_utils import LOSS_MAPPING
#   File "/usr/local/lib/python3.12/dist-packages/transformers/loss/loss_utils.py", line 21, in <module>
#     from .loss_deformable_detr import DeformableDetrForObjectDetectionLoss, DeformableDetrForSegmentationLoss
#   File "/usr/local/lib/python3.12/dist-packages/transformers/loss/loss_deformable_detr.py", line 4, in <module>
#     from ..image_transforms import center_to_corners_format
#   File "/usr/local/lib/python3.12/dist-packages/transformers/image_transforms.py", line 47, in <module>
#     import tensorflow as tf
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/__init__.py", line 49, in <module>
#     from tensorflow._api.v2 import __internal__
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/_api/v2/__internal__/__init__.py", line 11, in <module>
#     from tensorflow._api.v2.__internal__ import distribute
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/_api/v2/__internal__/distribute/__init__.py", line 8, in <module>
#     from tensorflow._api.v2.__internal__.distribute import combinations
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/_api/v2/__internal__/distribute/combinations/__init__.py", line 8, in <module>
#     from tensorflow.python.distribute.combinations import env # line: 456
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/distribute/combinations.py", line 33, in <module>
#     from tensorflow.python.distribute import collective_all_reduce_strategy
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/distribute/collective_all_reduce_strategy.py", line 26, in <module>
#     from tensorflow.python.distribute import cross_device_ops as cross_device_ops_lib
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/distribute/cross_device_ops.py", line 28, in <module>
#     from tensorflow.python.distribute import cross_device_utils
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/distribute/cross_device_utils.py", line 22, in <module>
#     from tensorflow.python.distribute import values as value_lib
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/distribute/values.py", line 23, in <module>
#     from tensorflow.python.distribute import distribute_lib
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/distribute/distribute_lib.py", line 205, in <module>
#     from tensorflow.python.data.ops import dataset_ops
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/data/__init__.py", line 21, in <module>
#     from tensorflow.python.data import experimental
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/data/experimental/__init__.py", line 99, in <module>
#     from tensorflow.python.data.experimental import service
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/data/experimental/service/__init__.py", line 419, in <module>
#     from tensorflow.python.data.experimental.ops.data_service_ops import distribute
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/data/experimental/ops/data_service_ops.py", line 23, in <module>
#     from tensorflow.python.data.experimental.ops import compression_ops
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/data/experimental/ops/compression_ops.py", line 16, in <module>
#     from tensorflow.python.data.util import structure
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/data/util/structure.py", line 32, in <module>
#     from tensorflow.python.ops.ragged import ragged_tensor
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/ragged/__init__.py", line 28, in <module>
#     from tensorflow.python.ops.ragged import ragged_tensor
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/ragged/ragged_tensor.py", line 3149, in <module>
#     from tensorflow.python.ops.ragged import ragged_ops  # pylint: disable=unused-import, g-bad-import-order, g-import-not-at-top
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/ragged/ragged_ops.py", line 41, in <module>
#     from tensorflow.python.ops.ragged import ragged_image_ops
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/ragged/ragged_image_ops.py", line 24, in <module>
#     from tensorflow.python.ops import image_ops
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/image_ops.py", line 159, in <module>
#     from tensorflow.python.ops.image_ops_impl import *
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/image_ops_impl.py", line 40, in <module>
#     from tensorflow.python.ops import nn_impl
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/nn_impl.py", line 26, in <module>
#     from tensorflow.python.ops import ctc_ops  # pylint: disable=unused-import
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/ctc_ops.py", line 32, in <module>
#     from tensorflow.python.ops import custom_gradient
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/custom_gradient.py", line 17, in <module>
#     from tensorflow.python.eager import backprop
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/eager/backprop.py", line 45, in <module>
#     from tensorflow.python.ops import gradients_impl  # pylint: disable=unused-import
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/gradients_impl.py", line 33, in <module>
#     from tensorflow.python.ops import math_grad  # pylint: disable=unused-import
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/math_grad.py", line 1215, in <module>
#     @ops.RegisterGradient("Polygamma")
#      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/ops.py", line 1722, in __call__
#     gradient_registry.register(f, self._op_type)
#   File "/usr/local/lib/python3.12/dist-packages/tensorflow/python/framework/registry.py", line 65, in register
#     stack = traceback.extract_stack(limit=3)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/traceback.py", line 232, in extract_stack
#     stack = StackSummary.extract(walk_stack(f), limit=limit)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/traceback.py", line 395, in extract
#     return klass._extract_from_extended_frame_gen(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/traceback.py", line 434, in _extract_from_extended_frame_gen
#     linecache.checkcache(filename)
#   File "/usr/lib/python3.12/linecache.py", line 75, in checkcache
#     stat = os.stat(fullname)
#            ^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
